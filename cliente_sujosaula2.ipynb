# %% [markdown]
# <a href="https://colab.research.google.com/github/ale-lsf/machine-fork/blob/main/cliente_sujosaula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd   # Importa a biblioteca Pandas e dá a ela o apelido "pd".

# %%
df = pd.read_csv("clientes_sujo.csv")   # Lê o arquivo CSV e armazena seus dados em um DataFrame chamado df.

# %%
df.head(10)   # Mostra as 10 primeiras linhas do DataFrame.

# %%
df.shape   # Retorna uma tupla no formato (linhas, colunas).

# %%
df.columns   # Exibe o nome de todas as colunas da planilha.

# %%
df.dtypes   # Mostra o tipo de dado de cada coluna (int, float, object, datetime etc.).

# %%
df.info()   # Exibe informações gerais da tabela, como quantidade de linhas, colunas e valores nulos.

# %%
df.describe()   # Calcula média, mediana, mínimo, máximo, desvio padrão e outras estatísticas.

# %%
df.isnull().sum()   # Conta quantos valores ausentes existem em cada coluna.

# %%
media_idade = df["Idade"].mean()   # Calcula a média da coluna "Idade".

# %%
media_idade = df["Idade"].mean()   # Calcula a média da coluna "Idade".

# %%
media_idade = df["Idade"].mean()   # Calcula a média da idade.

df["Idade"] = df["Idade"].fillna(media_idade)   # Substitui os valores nulos pela média calculada.
